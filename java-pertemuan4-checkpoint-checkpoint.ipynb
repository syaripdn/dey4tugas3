// %%
    //Tugas 4.1     
                            {
        int[] nilai ={3,6,3};
        
        System.out.println(nilai[0]);
        System.out.println(nilai[1]);
        System.out.println(nilai[2]);
        }
//Menghasilkan Nilai 3,6,3 dalam bentuk vertikal. kesimpulanya code program lebih simpel
// Out:
// 3
// 6
// 3
// null

// %%
     //Tugas 4.2
     //Program 4.2
        int arr[]={3,6,3};  
        for(int n:arr){  
            System.out.println("Tinggi adalah:"+n);  
        }  
    //Menampilakan indext dengan nilai 3
// Out:
// Tinggi adalah:3
// Tinggi adalah:6
// Tinggi adalah:3
// null

// %%
     //Tugas 4.3
     //Program 4.2
        int arr[]={5,6,3};  
        for(int n:arr){  
            System.out.println("Tinggi adalah:"+n);  
        }  
    //Hasil modifikasi
// Out:
// Tinggi adalah:5
// Tinggi adalah:6
// Tinggi adalah:3
// null

// %% [markdown]
// Tugas 4.4
// potongan kode dibawah ini menggunakan fungsi Arrays.sort, jalankan sempurnakan jika ada error/kesalahan

// %%
//Program 4.3 
import java.util.Arrays;


   int[] tinggi;
   Tinggi = new int[3];
   tinggi[0]; : 5;  //asignment
   tinggi[1]; : 6;
   tinggi[2]; : 3;
   Arrays.sort(tinggi);   
   for(n:tinggi) {
       System.out.println("Tinggi adalah"+n);
   }
// Out:
// not a statement
//  tinggi[0]
//  ^        ^
//
// not a statement
//   5
//   ^^
//
// not a statement
//  tinggi[1]
//  ^        ^
//
// illegal start of expression
//  : 6
//  ^
//
// not a statement
//  : 6
//    ^^
//
// not a statement
//  tinggi[2]
//  ^        ^
//
// illegal start of expression
//  : 3
//  ^
//
// not a statement
//  : 3
//    ^^
//
// bad initializer for for-loop
//  for(n:tinggi) {
//      ^

// %% [markdown]
// Aray: Dua Dimensi
// Deklarasi dan inisiasi array dua dimensi adalah sebagai berikut:
//
// double[][] matriks = new double[1][1];

// %%
//Program 4.4
   double[][] matriks = new double[2][2];  // 2 x 2
   
   matriks[0][0] = 0;
   matriks[0][1] = 1;   
   matriks[1][0] = 2;
   matriks[1][1] = 3;
   
   //cara biasa
   for(int i=0;i<matriks.length;i++) {
       for (int j=0;j<matriks[i].length;j++) {
         System.out.printf("Nilai [%d,%d] = %4.2f \n",i,j,matriks[i][j]);  
       }      
   }
   
   //cara foreach
   for(double[] baris:matriks) {
       for (double val:baris) {
         System.out.println("Nilai = "+val);  
       }      
   }
// Out:
// Nilai [0,0] = 0.00
// Nilai [0,1] = 1.00
// Nilai [1,0] = 2.00
// Nilai [1,1] = 3.00
// Nilai = 0.0
// Nilai = 1.0
// Nilai = 2.0
// Nilai = 3.0
// null

// %%
// membuat array
String[] nama = {"Linda", "Santi", "Susan", "Mila", "Ayu"};

// mengambil data array
System.out.println("teman"[2]);
// Out:
// array required, but java.lang.String found
//  System.out.println("teman"[2])
//                     ^         ^

// %%
    int x [][]= new int [4][4];
    int y [][]= new int [4][4];
    int z [][]= new int [4][4];
        System.out.println("Masukkan Elemen Matriks Pertama");
        for (int i = 0; i < 4; i++) {
        for (int j = 0; j < 4; j++) {
        System.out.print("Elemen ("+(i+1)+" , "+(j+1)+") : ");
        x[i][j]= masuk.nextInt();
        }
        }
        System.out.println("\nMatriks Pertama");
        for (int i=0;i<4;i++)
        for (int j=0;j<4;j++)
                System.out.print(x[i][j]+" ");
                System.out.println();}
        System.out.println("");
        System.out.println("Masukkan Elemen Matriks Kedua");
        for (int k = 0; k < 4; k++) {
        for (int l = 0; l < 4; l++) {
        System.out.print("Elemen ("+(k+1)+" , "+(l+1)+") : ");
        y[k][l]= masuk.nextInt();
        }
        }
        System.out.println("\nMatriks Kedua");
        for (int k=0;k<4;k++){
        for (int l=0;l<4;l++)
                System.out.print(y[k][l]+" ");
                System.out.println();}
        z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0];
        z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][1]+x[0][2]*y[2][1]+x[0][3]*y[3][1];
        z[0][2]= x[0][0]*y[0][2]+x[0][1]*y[1][2]+x[0][2]*y[2][2]+x[0][3]*y[3][2];
        z[0][3]= x[0][0]*y[0][3]+x[0][1]*y[1][3]+x[0][2]*y[2][3]+x[0][3]*y[3][3];
        z[1][0]= x[1][0]*y[0][0]+x[1][1]*y[1][0]+x[1][2]*y[2][0]+x[1][3]*y[3][0];
        z[1][1]= x[1][0]*y[0][1]+x[1][1]*y[1][1]+x[1][2]*y[2][1]+x[1][3]*y[3][1];
        z[1][2]= x[1][0]*y[0][2]+x[1][1]*y[1][2]+x[1][2]*y[2][2]+x[1][3]*y[3][2];
        z[1][3]= x[1][0]*y[0][3]+x[1][1]*y[1][3]+x[1][2]*y[2][3]+x[1][3]*y[3][3];
        z[2][0]= x[2][0]*y[0][0]+x[2][1]*y[1][0]+x[2][2]*y[2][0]+x[2][3]*y[3][0];
        z[2][1]= x[2][0]*y[0][1]+x[2][1]*y[1][1]+x[2][2]*y[2][1]+x[2][3]*y[3][1];
        z[2][2]= x[2][0]*y[0][2]+x[2][1]*y[1][2]+x[2][2]*y[2][2]+x[2][3]*y[3][2];
        z[2][3]= x[2][0]*y[0][3]+x[2][1]*y[1][3]+x[2][2]*y[2][3]+x[2][3]*y[3][3];
        z[3][0]= x[3][0]*y[0][0]+x[3][1]*y[1][0]+x[3][2]*y[2][0]+x[3][3]*y[3][0];
        z[3][1]= x[3][0]*y[0][1]+x[3][1]*y[1][1]+x[3][2]*y[2][1]+x[3][3]*y[3][1];
        z[3][2]= x[3][0]*y[0][2]+x[3][1]*y[1][2]+x[3][2]*y[2][2]+x[3][3]*y[3][2];
        z[3][3]= x[3][0]*y[0][3]+x[3][1]*y[1][3]+x[3][2]*y[2][3]+x[3][3]*y[3][3];
     
        System.out.println("\nMatrix Pertama * Matrix Kedua = ");
        for(int m = 0; m < 4; m++){
        for(int n = 0; n < 4; n++)
        System.out.print(z[m][n]+" ");
        System.out.println();}
    }
// Out:
// <identifier> expected
//  System.out.println("")
//                    ^
//
// illegal start of type
//  System.out.println("")
//                     ^
//
// <identifier> expected
//  System.out.println("Masukkan Elemen Matriks Kedu
//                    ^
//
// illegal start of type
//  System.out.println("Masukkan Elemen Matriks Kedua
//                     ^
//
// illegal start of type
//  for (int k = 0
//  ^
//
// ')' expected
//  for (int k = 0
//            ^
//
// illegal start of type
//  for (int k = 0
//               ^^
//
// <identifier> expected
//  for (int k = 0
//                ^
//
// ';' expected
//  k < 4
// ^
//
// <identifier> expected
//  k < 4
//     ^
//
// illegal start of type
//  k < 4; k++) {
//       ^^
//
// '(' expected
//  k++) {
//   ^
//
// <identifier> expected
//  System.out.println("\nMatriks Kedua")
//                    ^
//
// illegal start of type
//  System.out.println("\nMatriks Kedua")
//                     ^
//
// illegal start of type
//  for (int k=0
//  ^
//
// ')' expected
//  for (int k=0
//            ^
//
// illegal start of type
//  for (int k=0
//             ^^
//
// <identifier> expected
//  for (int k=0
//              ^
//
// ';' expected
// k<4
// ^
//
// <identifier> expected
// k<4
//   ^
//
// illegal start of type
// k<4;k++){
//    ^^
//
// '(' expected
// k++){
//  ^
//
// ']' expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]
//    ^
//
// ';' expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*
//     ^
//
// illegal start of type
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[
//      ^^
//
// <identifier> expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[
//       ^
//
// ';' expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1
//        ^
//
// illegal start of type
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][
//         ^^
//
// ']' expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+
//             ^
//
// illegal start of type
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[
//              ^^
//
// <identifier> expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[
//               ^
//
// ';' expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0
//                ^
//
// illegal start of type
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][
//                 ^^
//
// <identifier> expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][
//                  ^
//
// ';' expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2
//                   ^
//
// illegal start of type
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*
//                    ^^
//
// <identifier> expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*
//                     ^
//
// ';' expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y
//                      ^
//
// illegal start of type
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2
//                       ^^
//
// <identifier> expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2
//                        ^
//
// ';' expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2]
//                         ^
//
// illegal start of type
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0
//                          ^^
//
// ']' expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+
//                             ^
//
// illegal start of type
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[
//                              ^^
//
// <identifier> expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[
//                               ^
//
// ';' expected
//  z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0
//                                ^
//
// illegal start of type
// z[0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][
//                                ^^
//
// <identifier> expected
// [0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][
//                                ^
//
// ';' expected
// 0][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3
//                                ^
//
// illegal start of type
// ][0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*
//                                ^^
//
// <identifier> expected
// [0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*
//                                ^
//
// ';' expected
// 0]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y
//                                ^
//
// illegal start of type
// ]= x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3
//                                ^^
//
// <identifier> expected
// = x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3
//                                ^
//
// ';' expected
//  x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3]
//                                ^
//
// illegal start of type
// x[0][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0
//                                ^^
//
// ']' expected
// ][0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// illegal start of type
// [0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^^
//
// <identifier> expected
// 0]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// ';' expected
// ]*y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// illegal start of type
// *y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^^
//
// <identifier> expected
// y[0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// ';' expected
// [0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// illegal start of type
// 0][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^^
//
// <identifier> expected
// ][0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// ';' expected
// [0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// illegal start of type
// 0]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^^
//
// <identifier> expected
// ]+x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// ';' expected
// +x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// illegal start of type
// x[0][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^^
//
// ']' expected
// ][1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// illegal start of type
// [1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^^
//
// <identifier> expected
// 1]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// ';' expected
// ]*y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// illegal start of type
// *y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^^
//
// <identifier> expected
// y[1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// ';' expected
// [1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// illegal start of type
// 1][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^^
//
// <identifier> expected
// ][0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// ';' expected
// [0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// illegal start of type
// 0]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^^
//
// <identifier> expected
// ]+x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// ';' expected
// +x[0][2]*y[2][0]+x[0][3]*y[3][0]
//                                ^
//
// ']' expected
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]
//    ^
//
// ';' expected
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*
//     ^
//
// illegal start of type
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[
//      ^^
//
// <identifier> expected
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[
//       ^
//
// ';' expected
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1
//        ^
//
// illegal start of type
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][
//         ^^
//
// ']' expected
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][1]+
//             ^
//
// illegal start of type
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][1]+x[
//              ^^
//
// <identifier> expected
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][1]+x[
//               ^
//
// ';' expected
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][1]+x[0
//                ^
//
// illegal start of type
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][1]+x[0][
//                 ^^
//
// <identifier> expected
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][1]+x[0][
//                  ^
//
// ';' expected
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][1]+x[0][2
//                   ^
//
// illegal start of type
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][1]+x[0][2]*
//                    ^^
//
// <identifier> expected
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][1]+x[0][2]*
//                     ^
//
// ';' expected
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][1]+x[0][2]*y
//                      ^
//
// illegal start of type
//  z[0][1]= x[0][0]*y[0][1]+x[0][1]*y[1][1]+x[0][2]*y[2
//                       ^^
